# %% [markdown]
# # Fazendo as primeiras visualizações

# %%
import os
import pandas as pd
# pd.options.plotting.backend = "plotly"

from util import *

# sns.set(rc={"figure.figsize": (20,8)}, font_scale=2)

# %%
local_dados = "./../data/"
dic_list = os.listdir(local_dados)
dic_list = [local_dados+i for i in dic_list]
printLis(dic_list)
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> ./../data/iris.csv
# 1 -> ./../data/monitoramento_tempo.csv

# %%
# monitoramento_tempo.csv
df = pd.read_csv(dic_list[1])
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df['data'] = pd.to_datetime(df['data'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['data'], df['temperatura'])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(df['data'], df['temperatura'])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('Temperatura no Tempo')
plt.plot(df['data'], df['temperatura'])
plt.show()

# %% [markdown]
# # Funcionalidades básicas do matplotlib

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.set_title("Temperatura no Momento")
eixo.plot(df['data'], df['temperatura'])
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento")

eixo.plot(df['data'], df['temperatura'])

eixo.set_xlabel("Data")
eixo.set_ylabel("Temperatura")

plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'])

eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'])

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'])

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

eixo.legend(["Temperatura"], loc='lower right', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'], color='g')

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

eixo.legend(["Temperatura"], loc='lower right', fontsize=15)

plt.show()

# %% [markdown]
# # Espessura, estilo, foco, marcadores e grades

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'], color='g', lw=4)

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

eixo.legend(["Temperatura"], loc='lower right', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'], color='g', lw=0.3)

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

eixo.legend(["Temperatura"], loc='lower right', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'], color='g', ls='dotted')

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

eixo.legend(["Temperatura"], loc='lower right', fontsize=15)

plt.show()

# %%
from datetime import datetime

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'], color='g')

eixo.set_xlim(datetime(2014,1,1),datetime(2015,1,1))

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura", fontsize=20)

eixo.legend(["Temperatura"], loc='lower right', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'], color='g', marker='o')

eixo.set_xlim(datetime(2014,1,1),datetime(2015,1,1))

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura", fontsize=20)

eixo.legend(["Temperatura"], loc='lower right', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25)

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.grid(True)

eixo.set_xlim(datetime(2014,1,1),datetime(2015,1,1))

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura (Kelven)", fontsize=20)

eixo.legend(["Temperatura"], loc='lower right', fontsize=15)

plt.show()

# %% [markdown]
# # Mais de um eixo na mesma visualização

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

eixo.set_title("Temperatura no Momento", fontsize=25, pad=20)

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.grid(True)
eixo.legend(['Temperatura'], loc='best', fontsize=15)

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura (Kelven)", fontsize=20)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

# ________________________________________________________________________
eixo.set_title("Temperatura no Momento", fontsize=25, pad=20)

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.grid(True)
eixo.legend(['Temperatura'], loc='best', fontsize=15)

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura (Kelven)", fontsize=20)

# ________________________________________________________________________
eixo2.set_title("Temperatura no Momento", fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.grid(True)
eixo2.legend(['Temperatura'], loc='best', fontsize=10)

eixo2.tick_params(labelsize=10)

eixo2.set_xlabel("Data", fontsize=15)

eixo2.set_ylabel("Temperatura (Kelven)", fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.6,0.55,0.39,0.4])

# ________________________________________________________________________
eixo.set_title("Temperatura em 2014", fontsize=25, pad=20)

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.grid(True)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)

eixo.set_xlim(datetime(2014,1,1),datetime(2015,1,1))

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura (Kelven)", fontsize=20)

# ________________________________________________________________________
eixo2.set_title("Temperatura na Série Histórica", fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.grid(True)
eixo2.legend(['Temperatura'], loc='best', fontsize=10)

eixo2.tick_params(labelsize=15)

eixo2.set_xlabel("Data", fontsize=15)

eixo2.set_ylabel("Temperatura (Kelven)", fontsize=15)

plt.show()

# %% [markdown]
# # Uma visualização mais complexa

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.6,0.55,0.37,0.4])

# ________________________________________________________________________
eixo.set_title("Temperatura em Maio de 2014", fontsize=25, pad=20)

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.grid(True)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)

eixo.set_xlim(datetime(2014,5,1),datetime(2014,6,1))

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura (Kelven)", fontsize=20)

# ________________________________________________________________________
eixo2.set_title("Temperatura em 2014", fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.grid(True)
eixo2.legend(['Temperatura'], loc='best', fontsize=10)

eixo2.set_xlim(datetime(2014,1,1),datetime(2015,1,1))

eixo2.tick_params(labelsize=15)

eixo2.set_xlabel("Data", fontsize=15)
for tick in eixo2.get_xticklabels():
    tick.set_rotation(45)

eixo2.set_ylabel("Temperatura (Kelven)", fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.6,0.55,0.37,0.4])

# ________________________________________________________________________
eixo.set_title("Temperatura em Maio de 2014", fontsize=25, pad=20)

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.grid(True)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)

eixo.set_xlim(datetime(2014,5,1),datetime(2014,6,1))
eixo.set_ylim(270,350)

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura (Kelven)", fontsize=20)

# ________________________________________________________________________
eixo2.set_title("Temperatura em 2014", fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.grid(True)
eixo2.legend(['Temperatura'], loc='best', fontsize=10)

eixo2.set_xlim(datetime(2014,1,1),datetime(2015,1,1))

eixo2.tick_params(labelsize=15)

eixo2.set_xlabel("Data", fontsize=15)
for tick in eixo2.get_xticklabels():
    tick.set_rotation(45)

eixo2.set_ylabel("Temperatura (Kelven)", fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.6,0.55,0.37,0.4])

# ________________________________________________________________________
eixo.set_title("Temperatura em Maio de 2014", fontsize=25, pad=20)

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.grid(True)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)

eixo.set_xlim(datetime(2014,5,1),datetime(2014,6,1))
eixo.set_ylim(270,350)

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura (Kelven)", fontsize=20)

azul_esquerda = df['data'] < datetime(2014,5,1)
azul_direita = df['data'] > datetime(2014,6,1)

# ________________________________________________________________________
eixo2.set_title("Temperatura em 2014", fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color='g')
eixo2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'], color='b')
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color='b')

eixo2.grid(True)
eixo2.legend(['Temperatura'], loc='best', fontsize=10)

eixo2.set_xlim(datetime(2014,1,1),datetime(2015,1,1))

eixo2.tick_params(labelsize=15)

eixo2.set_xlabel("Data", fontsize=15)
for tick in eixo2.get_xticklabels():
    tick.set_rotation(45)

eixo2.set_ylabel("Temperatura (Kelven)", fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_xlim(datetime(2014,1,1), datetime(2015,1,1))
eixo.set_title('Temperatura em 2014', fontsize=25, pad = 20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize= 15)

eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.legend(['Temperatura'], loc = 'lower right') 
eixo2.set_title('Temperatura 2012-2018', fontsize=15)

# %% [markdown]
# # Linhas de restrição e anotações

# %%
fig =  plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25, pad=20)
eixo.plot(df['data'], df['temperatura'], color='g')
eixo.legend(['Temperatura'], loc="lower right", fontsize=15)
eixo.grid(True)

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

for t in eixo.get_xticklabels():
  t.set_rotation(45)

eixo.axhline(max(df['temperatura']), color='k', linestyle='--')
eixo.axhline(min(df['temperatura']), color='k', linestyle='--')

plt.show()

# %%
fig =  plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25, pad=20)
eixo.plot(df['data'], df['temperatura'], color='g')
eixo.legend(['Temperatura'], loc="lower right", fontsize=15)
eixo.grid(True)

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

for t in eixo.get_xticklabels():
  t.set_rotation(45)

x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

eixo.annotate("Máximo", xy=(x1,y1), fontsize=20)

eixo.axhline(max(df['temperatura']), color='k', linestyle='--')
eixo.axhline(min(df['temperatura']), color='k', linestyle='--')

plt.show()

# %% [markdown]
# # Mais anotações e setas

# %%
fig =  plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25, pad=20)
eixo.plot(df['data'], df['temperatura'], color='g')
eixo.legend(['Temperatura'], loc="lower right", fontsize=15)
eixo.grid(True)

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

for t in eixo.get_xticklabels():
  t.set_rotation(45)

x1 = df['data'][df['temperatura'].idxmax() - 1000]
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura']) - 5

eixo.annotate(
    "Máximo",
    xy=(x1,y1),
    fontsize=20,
    xytext=(x2,y2),
    arrowprops=dict(facecolor='k')
)

eixo.axhline(max(df['temperatura']), color='k', linestyle='--')
eixo.axhline(min(df['temperatura']), color='k', linestyle='--')

plt.show()

# %%
fig =  plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])

eixo.set_title("Temperatura no Momento", fontsize=25, pad=20)
eixo.plot(df['data'], df['temperatura'], color='g')
eixo.legend(['Temperatura'], loc="lower right", fontsize=15)
eixo.grid(True)

eixo.tick_params(labelsize=20)
eixo.set_xlabel("Data", fontsize=20)
eixo.set_ylabel("Temperatura", fontsize=20)

for t in eixo.get_xticklabels():
  t.set_rotation(45)

x1 = df['data'][df['temperatura'].idxmax() - 1000]
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura']) - 4

eixo.annotate(
    "Máximo",
    xy=(x1,y1),
    fontsize=20,
    xytext=(x2,y2),
    arrowprops=dict(facecolor='r')
)

x1 = df['data'][df['temperatura'].idxmin() - 1000]
y1 = min(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmin() - 7000]
y2 = min(df['temperatura']) + 4

eixo.annotate(
    "Mínimo",
    xy=(x1,y1),
    fontsize=20,
    xytext=(x2,y2),
    arrowprops=dict(facecolor='r')
)

eixo.axhline(max(df['temperatura']), color='r', linestyle='--')
eixo.axhline(min(df['temperatura']), color='r', linestyle='--')

plt.show()

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.6,0.55,0.37,0.4])

# ________________________________________________________________________
eixo.set_title("Temperatura em Maio de 2014", fontsize=25, pad=20)

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.grid(True)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)

eixo.set_xlim(datetime(2014,5,1),datetime(2014,6,1))
eixo.set_ylim(270,370)

eixo.tick_params(labelsize=20)

eixo.set_xlabel("Data", fontsize=20)
for tick in eixo.get_xticklabels():
    tick.set_rotation(45)

eixo.set_ylabel("Temperatura (Kelven)", fontsize=20)

# ________________________________________________________________________
azul_esquerda = df['data'] < datetime(2014,5,1)
azul_direita = df['data'] > datetime(2014,6,1)

eixo2.set_title("Temperatura em 2014", fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color='g')
eixo2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'], color='b')
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color='b')

eixo2.grid(True)
eixo2.legend(['Temperatura'], loc='best', fontsize=10)

eixo2.set_xlim(datetime(2014,1,1),datetime(2015,1,1))

eixo2.tick_params(labelsize=15)

eixo2.set_xlabel("Data", fontsize=15)
for tick in eixo2.get_xticklabels():
    tick.set_rotation(45)

eixo2.set_ylabel("Temperatura (Kelven)", fontsize=15)

# ________________________________________________________________________

maio = df[(df['data'] > datetime(2014,5,1)) & (df['data'] < datetime(2014,6,1))]

eixo.axhline(maio['temperatura'].max(), color='r', linestyle='--')

x1 = maio['data'][maio['temperatura'].idxmax() - 5]
y1 = maio['temperatura'].max()

x2 = maio['data'][maio['temperatura'].idxmax() - 200]
y2 = maio['temperatura'].max() + 5

eixo.annotate(
    "Máxima em Maio: " + str(y1),
    xy=(x1,y1),
    fontsize=20,
    xytext=(x2,y2),
    arrowprops=dict(facecolor='r')
)

eixo.axhline(maio['temperatura'].min(), color='r', linestyle='--')

x1 = maio['data'][maio['temperatura'].idxmin() + 5]
y1 = maio['temperatura'].min()

x2 = maio['data'][maio['temperatura'].idxmin() + 50]
y2 = maio['temperatura'].min() - 6

eixo.annotate(
    "Mínima em Maio: "+ str(y1),
    xy=(x1,y1),
    fontsize=20,
    xytext=(x2,y2),
    arrowprops=dict(facecolor='r')
)

plt.show()
resultados = "./results/"
if not os.path.exists(resultados):
    os.makedirs(resultados)
    
fig.savefig(resultados+'time_series.png', bbox_inches='tight', dpi=300)

# %%
asdasd
